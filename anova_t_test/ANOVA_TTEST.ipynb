# %%
pip install tf-nightly-gpu
# Out:
# ...
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# ...
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4848 sha256=402a11937b5be80baf5fd07429dae98d07fbbb7ba6b7f9d2fc3f8f82b19ced48
#   Stored in directory: c:\users\manas\appdata\local\pip\cache\wheels\b6\0d\90\0d1bbd99855f99cb2f6c2e5ff96f8023fad8ec367695f7d72d
# Successfully built termcolor
# ...
# Note: you may need to restart the kernel to use updated packages.
